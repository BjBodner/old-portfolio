# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


import My_Image_Functions1
import Optimization_Section_With_Two_Mode_For_Visualization
# Out:
# Initial Total_Resources 60.0
#
# Minimum Resouces test
# ------------------------------------------------------------------
# Minimal_Allocation is: 3
# (Maximal_Allocation is: 19 )
# Total_Resources After minumum resource allocation Test 60
#
# Maximum Resouces test
# ------------------------------------------------------------------
# Maximal_Allocation is: 27
# (Minimal_Allocation is: 11 )
# Total_Resources After maximum resource allocation Test 60
# Current_Resource_Allocation [15 15 15 15]
# ____________________________________________________
# Iteration 1 \ 10
# Current_Resource_Allocation [15 15 15 15]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 12152.725068384805 After Running Iteration 1 \ 10
# the Random_Search_exponential_Growth_Factors are : 2.0 2.0 2.0 2.0
# the Targeted_Search_exponential_Growth_Factor is: 0 0 0 0
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 2 \ 10
# Current_Resource_Allocation [18 11  9 22]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 8877.452461766508 After Running Iteration 2 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 1 1 1 1
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 3 \ 10
# Current_Resource_Allocation [15 12 17 16]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 7848.460329111766 After Running Iteration 3 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 2 2 2 2
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 4 \ 10
# Current_Resource_Allocation [11 27 11 11]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 7848.460329111766 After Running Iteration 4 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 3 3 3 3
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 5 \ 10
# Current_Resource_Allocation [15 15 15 15]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 7595.546778292948 After Running Iteration 5 \ 10
# the Random_Search_exponential_Growth_Factors are : 2 2 2 2
# the Targeted_Search_exponential_Growth_Factor is: 0 0 0 0
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 6 \ 10
# Current_Resource_Allocation [17  9 19 15]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 6676.110628640922 After Running Iteration 6 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 1 1 1 1
# ---------------------------------------------------------------------
#
# hyperparameter Summary:
# ---------------------------------------------------------------------
# After Running hyperparameter Iteration 0 \ 3
# Cost_Function_For_Hyperparameter_Optimization [-565.7834528  -542.39174736 -655.10969157 -514.93267617]
#
# Best_Individual_Hyperparameters [2.66812615 8.33487762 2.52773331 2.28201539 3.58822149 1.
#  8.94745473 1.        ]
#
# the Random_Search_exponential_Growth_Factor for the hyperparameter search is: 1
# the Targeted_Search_exponential_Growth_Factor for the hyperparameter search is: 0
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 7 \ 10
# Current_Resource_Allocation [15 15 16 14]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 6397.13189161343 After Running Iteration 7 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 2 2 2 2
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 8 \ 10
# Current_Resource_Allocation [15 10 25 10]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 6397.13189161343 After Running Iteration 8 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 3 3 3 3
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 9 \ 10
# Current_Resource_Allocation [15 15 15 15]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 6193.713642731735 After Running Iteration 9 \ 10
# the Random_Search_exponential_Growth_Factors are : 2 2 2 2
# the Targeted_Search_exponential_Growth_Factor is: 0 0 0 0
# ---------------------------------------------------------------------
#
# hyperparameter Summary:
# ---------------------------------------------------------------------
# After Running hyperparameter Iteration 1 \ 3
# Cost_Function_For_Hyperparameter_Optimization [-147.99818824 -135.61216592 -215.25607805  -73.86395064]
#
# Best_Individual_Hyperparameters [2.62447905 8.22592443 2.49805624 2.37895909 3.58073676 0.99852897
#  8.91369969 1.        ]
#
# the Random_Search_exponential_Growth_Factor for the hyperparameter search is: 1
# the Targeted_Search_exponential_Growth_Factor for the hyperparameter search is: 1
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 10 \ 10
# Current_Resource_Allocation [17 16 15 12]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 5272.692478655734 After Running Iteration 10 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 1 1 1 1
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 11 \ 10
# Current_Resource_Allocation [16 14 15 15]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 5164.103895266555 After Running Iteration 11 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 2 2 2 2
# ---------------------------------------------------------------------
#
# ____________________________________________________
# Iteration 12 \ 10
# Current_Resource_Allocation [21 18  9 12]
# Run Summary:
# ---------------------------------------------------------------------
# CurrentCost is: 5164.103895266555 After Running Iteration 12 \ 10
# the Random_Search_exponential_Growth_Factors are : 1 1 1 1
# the Targeted_Search_exponential_Growth_Factor is: 3 3 3 3
# ---------------------------------------------------------------------
#
# hyperparameter Summary:
# ---------------------------------------------------------------------
# After Running hyperparameter Iteration 2 \ 3
# Cost_Function_For_Hyperparameter_Optimization [-623.53235091 -546.91433518 -614.01410938 -566.62581012]
#
# Best_Individual_Hyperparameters [2.62447905 8.22592443 2.49805624 2.37895909 3.58073676 0.99852897
#  8.91369969 1.        ]
#
# the Random_Search_exponential_Growth_Factor for the hyperparameter search is: 1
# the Targeted_Search_exponential_Growth_Factor for the hyperparameter search is: 2
# ---------------------------------------------------------------------
#
# Initial Cost 24.574710635019837
# Final Cost 9.375413823829075e-05
# log10 Total_Evaluations /D=  3.0791812460476247

# %%
def Create_Animation_From_png_files_in_Folder(image_folder,Video_name,fps):

    import cv2
    import os


    video_name = Video_name + '.avi'
    images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
    
    # images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
    frame = cv2.imread(os.path.join(image_folder, images[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(video_name, -1, fps, (width,height))        
    for i in range (0,len(images)):
        image = "image" + str(i) + ".png"
        video.write(cv2.imread(os.path.join(image_folder, image)))
    
    cv2.destroyAllWindows()
    video.release()
    print('Video Created')


    
    



def Record_video_from_computer_camera():

    ## Press "q" when done

    import numpy as np
    import cv2

    cap = cv2.VideoCapture(0)
    out = cv2.VideoWriter('output.avi', -1, 20.0, (640,480))

    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret==True:
            frame = cv2.flip(frame,0)

            # write the flipped frame
            out.write(frame)

            cv2.imshow('frame',frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    # Release everything if job is finished
    cap.release()
    out.release()
    cv2.destroyAllWindows()





def Create_Animation_From_png_files_in_Folder(image_folder,Video_name,fps):

    import cv2
    import os


    video_name = Video_name + '.avi'
    images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
    
    # images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
    frame = cv2.imread(os.path.join(image_folder, images[0]))
    height, width, layers = frame.shape
    video = cv2.VideoWriter(video_name, -1, fps, (width,height))

        
    for i in range (0,len(images)):
        image = "image" + str(i) + ".png"
        video.write(cv2.imread(os.path.join(image_folder, image)))
    
    cv2.destroyAllWindows()
    video.release()
    print('Video Created')


    
    
def Calculate_Random_Surface_Potential_at_Point(u,v,A ,Sigma,X_Center,Y_Center):

    z = np.zeros((u.shape))
    for i in range (0,Number_Of_Random_Peaks):
        z = z + A[i]*np.exp(-((u-X_Center[i])**2)/Sigma[i] -((v-Y_Center[i])**2)/Sigma[i])


    return z






def Gereate_Random_Surface(x,y,A ,Sigma,X_Center,Y_Center):
    z = np.zeros((x.shape))
    for i in range (0,Number_Of_Random_Peaks):
        z = z + A[i]*np.exp(-((x-X_Center[i])**2)/Sigma[i] -((y-Y_Center[i])**2)/Sigma[i])
    return z



def Gereate_Random_Surface_Parameters(x,y):
    Number_Of_Random_Peaks = 60
    Amplitude_Range_Of_Peaks = 20
    Width_Range_Of_Peaks = 10
    X_Center_Bias = 10
    X_Center_Range = 20
    Y_Center_Bias = 10
    Y_Center_Range = 20


    A = Amplitude_Range_Of_Peaks*(np.random.rand(Number_Of_Random_Peaks) - 0.5)
    Sigma = Width_Range_Of_Peaks*np.random.rand(Number_Of_Random_Peaks)
    X_Center = X_Center_Bias + X_Center_Range*(np.random.rand(Number_Of_Random_Peaks) - 0.5)
    Y_Center = Y_Center_Bias + Y_Center_Range*(np.random.rand(Number_Of_Random_Peaks) - 0.5)

    return A ,Sigma,X_Center,Y_Center,Number_Of_Random_Peaks



x = np.linspace(0,20,500)
y = np.linspace(0,20,500)

x,y = np.meshgrid(x,y)

A ,Sigma,X_Center,Y_Center,Number_Of_Random_Peaks = Gereate_Random_Surface_Parameters(x,y)

z = Gereate_Random_Surface(x,y,A ,Sigma,X_Center,Y_Center)
print(np.zeros((z.shape)).shape)


fig = plt.figure(figsize=(20,10))
ax = fig.gca()
surf = ax.contour(x,y,z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# Out:
# (500, 500)

# %%
# def fun(x):
#     return np.sum((x-2)**2)


def fun(x):
    return Calculate_Random_Surface_Potential_at_Point(x[0],x[1],A ,Sigma,X_Center,Y_Center)
    
    

x0 = 5 + 1*(np.random.rand(2)-0.5)
Optimization_Iterations = 50 ## Parallel iterations for each run of the algorithm
print_Cost = 0

x_1 = x0
print("Function Value Before Optimization",fun(x0))
xmin,Samples_In_Each_Iteration,Best_Individual_In_Each_Iteration =  Optimization_Section_With_Two_Mode_For_Visualization.Orchestra_Optimize_With_Two_Mode_Section_For_Visualization(x_1,fun,Optimization_Iterations)
print("Function Value After Optimization",fun(xmin))


x_1 = x0
def Re_Initialize_Problem():
    x0 = 5 + 1*(np.random.rand(2)-0.5)
    z = Gereate_Random_Surface(x,y,A ,Sigma,X_Center,Y_Center)
    return x0,z


I = np.where(z == z.min())
I1 = I[0][0]
I2 = I[1][0]
x_global_Minima = x[I1,I2]
y_global_Minima = y[I1,I2]



Number_Of_Initializations = 10
for i in range(0,Number_Of_Initializations):
    A ,Sigma,X_Center,Y_Center,Number_Of_Random_Peaks = Gereate_Random_Surface_Parameters(x,y)
    x0,z = Re_Initialize_Problem()
    x_1 = x0


    I = np.where(z == z.min())
    I1 = I[0][0]
    I2 = I[1][0]
    x_global_Minima = x[I1,I2]
    y_global_Minima = y[I1,I2]
    k = 0

    print("")
    print("Re Initializeing:")
    print("---------------------------------------")
    print("Now the Global Minima is at",np.min(z))   
            
        
        
    print("Cost_Before Optimization:",fun(x_1)) 
#     Cost_Vector[i] = fun(x_1)

    x_1,Samples_In_Each_Iteration,Best_Individual_In_Each_Iteration =  Optimization_Section_With_Two_Mode_For_Visualization.Orchestra_Optimize_With_Two_Mode_Section_For_Visualization(x_1,fun,Optimization_Iterations)

    print("Cost_After Optimization:",fun(x_1))     
    
    
    for frame in range(0,Optimization_Iterations):
        fig = plt.figure(figsize=(5,5))
        ax = fig.gca()
        surf = ax.contour(x,y,z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)
        
        ax.scatter(x_global_Minima,y_global_Minima,linewidth=5,color='r',label='Global Minimum')
        ax.scatter(Samples_In_Each_Iteration[0,:,frame+1],Samples_In_Each_Iteration[1,:,frame+1],linewidth=0.01,color='0.5',label='Two Mode Section Samples')
        ax.scatter(Best_Individual_In_Each_Iteration[0,frame],Best_Individual_In_Each_Iteration[1,frame],linewidth=4,color='b',label='Best Two Mode Section')


        plt.title('Comparing Different Optimization Algorithms')
        ax.legend()
        plt.xlim(0,20)
        plt.ylim(0,20)
        plt.close(fig) ## this makes sure it is not displayed


        Folder_path = r'C:\Users\benjy\OneDrive\Brown\Research\Orchestra Optimization Algorithm\Visualizing_Optimization_Algorithms\Photos\image'
        Folder_path1 = Folder_path.replace('\\','/')
        filename = Folder_path1  + str(frame + i*Optimization_Iterations) + '.png'
        fig.savefig(filename)

    

print("Creating Video") 
Create_Animation_From_png_files_in_Folder('Photos','movie1',8)
# Out:
# Function Value Before Optimization 3.895912995596789
# Function Value After Optimization -2.522896818678151
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -17.501180186203555
# Cost_Before Optimization: -4.08438475387267
# Cost_After Optimization: -16.792595156270007
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -18.04639819389991
# Cost_Before Optimization: 3.0852500869886037
# Cost_After Optimization: -8.718223911170353
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -12.72443801468084
# Cost_Before Optimization: -2.271212222078038
# Cost_After Optimization: -12.724907086844926
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -21.028332829664876
# Cost_Before Optimization: -3.9878907276569655
# Cost_After Optimization: -6.724942548007851
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -20.089641366525832
# Cost_Before Optimization: -1.924198033211224
# Cost_After Optimization: -20.090526710993736
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -23.277340166759217
# Cost_Before Optimization: -2.263998462901038
# Cost_After Optimization: -19.119561200891983
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -14.42855362597001
# Cost_Before Optimization: 5.438874918347473
# Cost_After Optimization: -5.405035900753413
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -15.87641535463947
# Cost_Before Optimization: -11.226636648216877
# Cost_After Optimization: -14.652296678287613
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -19.031798946161672
# Cost_Before Optimization: -2.54831818713457
# Cost_After Optimization: -19.032458499076682
#
# Re Initializeing:
# ---------------------------------------
# Now the Global Minima is at -24.551683047112046
# Cost_Before Optimization: 3.1233163191211726
# Cost_After Optimization: -23.13850995916895
# Creating Video
# Video Created

# %%
I = np.argmin(z)
print(I)
print(np.min(z))
# print(z[I])

I = np.where(z == z.min())
I1 = I[0][0]
I2 = I[1][0]

print(I[1][0])
print(np.min(z))
print(z[I1,I2])
